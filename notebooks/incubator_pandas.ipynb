# %%
import pandas as pd

# %%
file = "incubator.xlsx"
df = pd.read_excel(file)

# %%
df
# Out:
#                     Name           Contact     BirdType  NumberOfEggs  \
# 0     Manuel Chapman Jr.  +263 737 070 090  geniue fowl            56
# 1            Mary Morgan      0712 474 894       turkey            88
# 2     Michelle Gutierrez      0771 690 526      broiler           411
# 3      William Hernandez        0775172685         duck           156
# 4          Blake Trevino  +263 715 379 507       turkey           157
# 5            Greg Thomas  +263 736 376 681       turkey             9
# 6         James Fletcher  +263 772 39 4032      broiler           462
# 7         Jonathan Moore  +263 737 904 310  geniue fowl           201
# 8        David Patterson  +263 736 547 696      broiler           287
# 9       Hannah Hernandez  +263 736 691 539  road runner            80
# 10           Jamie Brown      0733 512 376      broiler           170
# 11           Shawna Reed  +263 719 997 962       turkey           317
# ...

# %%
df['HatchRate(%)'].mean() # get average hatchRate of over the year of our incubator
# Out:
# 70.87249999999999

# %%
df.describe()  # get overall statistics
# Out:
#        NumberOfEggs  PricePerEgg($)  TotalPrice($)  HatchRate(%)
# count      40.00000        40.00000      40.000000     40.000000
# mean      257.00000         0.30250      77.688250     70.872500
# std       142.58259         0.13679      60.079677     11.768406
# min         9.00000         0.10000       3.600000     50.100000
# 25%       150.25000         0.20000      33.057500     59.950000
# 50%       228.50000         0.30000      61.550000     71.200000
# 75%       395.50000         0.40000     109.350000     81.800000
# max       475.00000         0.50000     237.500000     88.600000

# %%
df.sort_values('DateAdded')  # sort data by date
# Out:
#                     Name           Contact     BirdType  NumberOfEggs  \
# 25            George Lee        0775139057  road runner           207
# 10           Jamie Brown      0733 512 376      broiler           170
# 29         Joshua Glover      0717 999 661      broiler           151
# 4          Blake Trevino  +263 715 379 507       turkey           157
# 23          Jared Rangel      0770 636 451         duck           475
# 11           Shawna Reed  +263 719 997 962       turkey           317
# 36         Ronald Hughes  +263 711 662 250         duck           176
# 18           Dylan Short        0718932006  geniue fowl            74
# 17          Gary Santana  +263 733 949 344  geniue fowl           453
# 19         Scott Simmons  +263 736 332 811  geniue fowl            63
# 7         Jonathan Moore  +263 737 904 310  geniue fowl           201
# 28    Catherine Anderson      0739 098 157  road runner           409
# ...
