# %%
import pandas as pd
import os
os.getcwd()
# Out:
# '/home/donald/Projects/Python36/REST_API'

# %%
os.listdir()
# Out:
# ['Public_Health_Statistics-_Selected_underlying_causes_of_death_in_Chicago__2006___2010.csv',
#  'West_Nile_Virus_Cases__2006-present.csv',
#  'Untitled.ipynb',
#  '.~lock.Public_Health_Statistics-_Selected_underlying_causes_of_death_in_Chicago__2006___2010.csv#',
#  'Farmers_Markets_-_Map.csv',
#  'employee_restAPI',
#  'rows.csv',
#  '.ipynb_checkpoints',
#  'Chicago_Public_Schools_-_High_School_Progress_Report__2013-2014_.csv',
#  'CID-Cases-by-Disease-County-Year-Sex-DATA-DICTIONARY.xlsx',
#  'high_school_progressrepo.db']

# %%
fname = "Public_Health_Statistics-_Selected_underlying_causes_of_death_in_Chicago__2006___2010.csv" # load data to pd

# %%
df = pd.DataFrame(fname)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-3f95b6df7178> in <module>()
# ----> 1 df = pd.DataFrame(fname)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     420                                          dtype=values.dtype, copy=False)
#     421             else:
# --> 422                 raise ValueError('DataFrame constructor not properly called!')
#     423
#     424         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
df = pd.read_csv(fname)
df
# Out:
#                        Cause of Death  Community Area     Community Area Name  \
# 0                          All Causes               1             Rogers Park
# 1                          All Causes               2              West Ridge
# 2                          All Causes               3                  Uptown
# 3                          All Causes               4          Lincoln Square
# 4                          All Causes               5            North Center
# 5                          All Causes               6               Lake View
# 6                          All Causes               7            Lincoln Park
# 7                          All Causes               8         Near North Side
# 8                          All Causes               9             Edison Park
# 9                          All Causes              10            Norwood Park
# 10                         All Causes              11          Jefferson Park
# ...

# %%
df.tail()
# Out:
#                        Cause of Death  Community Area Community Area Name  \
# 1399  Suicide (intentional self-harm)              74     Mount Greenwood
# 1400  Suicide (intentional self-harm)              75         Morgan Park
# 1401  Suicide (intentional self-harm)              76              O'Hare
# 1402  Suicide (intentional self-harm)              77           Edgewater
# 1403  Suicide (intentional self-harm)               0             Chicago
#
#       Cumulative Deaths 2006 - 2010  Cumulative Deaths Rank  \
# 1399                              6                    51.0
# 1400                              4                    61.0
# 1401                              8                    40.0
# 1402                             32                     4.0
# 1403                            886                     NaN
#
#       Average Annual Deaths 2006 - 2010  Average Crude Rate 2006 - 2010  \
# 1399                                  1                             6.3
# ...

# %%
rows, columns = df.shape # show dimensions

# %%
rows
# Out:
# 1404

# %%
columns
# Out:
# 17

# %%
df[4:9]   # using python lists to get a number of data rows needed
# Out:
#   Cause of Death  Community Area Community Area Name  \
# 4     All Causes               5        North Center
# 5     All Causes               6           Lake View
# 6     All Causes               7        Lincoln Park
# 7     All Causes               8     Near North Side
# 8     All Causes               9         Edison Park
#
#    Cumulative Deaths 2006 - 2010  Cumulative Deaths Rank  \
# 4                            690                    59.0
# 5                           1914                    14.0
# 6                           1424                    30.0
# 7                           2054                    10.0
# 8                            520                    65.0
#
#    Average Annual Deaths 2006 - 2010  Average Crude Rate 2006 - 2010  \
# 4                                138                           433.0
# 5                                383                           405.3
# 6                                285                           443.9
# ...

# %%
df.columns
# Out:
# Index(['Cause of Death', 'Community Area', 'Community Area Name',
#        'Cumulative Deaths 2006 - 2010', 'Cumulative Deaths Rank',
#        'Average Annual Deaths 2006 - 2010', 'Average Crude Rate 2006 - 2010',
#        'Average Crude Rate Lower CI', 'Average Crude Rate Upper CI',
#        'Crude Rate Rank', 'Average Adjusted Rate 2006 - 2010',
#        'Average Adjusted Rate Lower CI', 'Average Adjusted Rate Upper CI',
#        'Adjusted Rate Rank',
#        'Average Annual Years of Potential Life Lost (YPLL) Rate 2006 - 2010',
#        'YPLL Rate RANK', 'WARNING'],
#       dtype='object')

# %%
df.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-412feca855b9> in <module>()
# ----> 1 df.rows
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
df['Cause of Death'] # get a column data of entire columns
# Out:
# 0                            All Causes
# 1                            All Causes
# 2                            All Causes
# 3                            All Causes
# 4                            All Causes
# 5                            All Causes
# 6                            All Causes
# 7                            All Causes
# 8                            All Causes
# 9                            All Causes
# 10                           All Causes
# 11                           All Causes
# 12                           All Causes
# 13                           All Causes
# 14                           All Causes
# 15                           All Causes
# 16                           All Causes
# 17                           All Causes
# 18                           All Causes
# 19                           All Causes
# 20                           All Causes
# 21                           All Causes
# 22                           All Causes
# ...

# %%
df[['Cause of Death', 'Average Adjusted Rate 2006 - 2010']] # show entire data of the given columnsb
# Out:
#                        Cause of Death  Average Adjusted Rate 2006 - 2010
# 0                          All Causes                              895.2
# 1                          All Causes                              689.9
# 2                          All Causes                              934.0
# 3                          All Causes                              698.7
# 4                          All Causes                              681.2
# 5                          All Causes                              599.5
# 6                          All Causes                              698.7
# 7                          All Causes                              518.9
# 8                          All Causes                              649.9
# 9                          All Causes                              699.6
# 10                         All Causes                              725.7
# 11                         All Causes                              572.5
# ...

# %%
df['Average Adjusted Rate 2006 - 2010'].max()
# Out:
# 1701.8

# %%
df.describe() # print stats on any integer/ float data of the given data sets
# Out:
#        Community Area  Cumulative Deaths 2006 - 2010  Cumulative Deaths Rank  \
# count     1404.000000                    1404.000000             1386.000000
# mean        38.500000                     383.134615               38.500000
# std         22.522832                    3308.331736               22.062244
# min          0.000000                       0.000000                1.000000
# 25%         19.000000                      16.000000               19.250000
# 50%         38.500000                      40.000000               38.500000
# 75%         58.000000                     159.250000               57.000000
# max         77.000000                   97851.000000               77.000000
#
#        Average Annual Deaths 2006 - 2010  Average Crude Rate 2006 - 2010  \
# count                        1404.000000                     1404.000000
# mean                           76.631766                      165.742877
# ...

# %%
'''
    * change data set
    * open Farmers_Markets_-_Map.csv data set
    * and do some basic pandas data manipulation on it
'''

# %%
farmers_data = "Farmers_Markets_-_Map.csv"
df = pd.read_csv(farmers_data)
df
# Out:
#                           LOCATION                      INTERSECTION  \
# 0                       Bridgeport                    35th & Wallace
# 1      Seaway Bank Farmer's Market                     645 E 87th St
# 2                          Beverly         W 95th St & S Longwood Dr
# 3                      Bronzeville         4400 S. Cottage Grove Ave
# 4                          Pullman  E 111th Pl & S Cottage Grove Ave
# 5                        Hyde Park                  53rd & Lake Park
# 6                    Printer's Row         S Dearborn St & W Polk St
# 7                      South Shore        E 70th St & S Jeffery Blvd
# 8           Wood Street Farm Stand                    5814 S Wood St
# 9        Rowan Tree Garden Society                   501 W Englewood
# 10                      Eden Place                4417 S Stewart Ave
# 11                     61st Street             6100 S Blackstone Ave
# 12         Pilsen Community Market                 1800 S Halsted St
# ...

# %%
df.describe() # get dataframe stats data
# Out:
#         LATITUDE  LONGITUDE
# count  17.000000  17.000000
# mean   41.803378 -87.636453
# std     0.053876   0.047051
# min    41.691825 -87.764587
# 25%    41.780690 -87.646795
# 50%    41.801971 -87.629130
# 75%    41.854924 -87.607847
# max    41.872827 -87.576348

# %%
df[df.DAY=="Tuesday"]   # get data on Tuesdays only
# Out:
#          LOCATION        INTERSECTION      DAY START TIME END TIME  \
# 13  Columbus Park  Harrison & Central  Tuesday    1:00 PM  7:00 PM
#
#     START DATE    END DATE                              WEBSITE    TYPE  \
# 13  06/26/2012  10/30/2012  http://www.chicagofarmersmarkets.us  Weekly
#
#    LINK ACCEPTED   LATITUDE  LONGITUDE                          Map
# 13           YES  41.872827 -87.764587  (41.87282668, -87.76458743)

# %%
df[df['LINK ACCEPTED']=="YES"]    # if your query contains space, use a json-like format
# Out:
#                           LOCATION                      INTERSECTION  \
# 0                       Bridgeport                    35th & Wallace
# 2                          Beverly         W 95th St & S Longwood Dr
# 3                      Bronzeville         4400 S. Cottage Grove Ave
# 4                          Pullman  E 111th Pl & S Cottage Grove Ave
# 5                        Hyde Park                  53rd & Lake Park
# 7                      South Shore        E 70th St & S Jeffery Blvd
# 8           Wood Street Farm Stand                    5814 S Wood St
# 10                      Eden Place                4417 S Stewart Ave
# 11                     61st Street             6100 S Blackstone Ave
# 12         Pilsen Community Market                 1800 S Halsted St
# 13                   Columbus Park                Harrison & Central
# 15           Homegrown Bronzeville                     343 E 51st St
# 16  Covenant Bank - North Lawndale                  1111 S Homan Ave
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=17, step=1)

# %%
df.set_index('START DATE')   # set a customised index
# Out:
#                                   LOCATION                      INTERSECTION  \
# START DATE
# 06/16/2012                      Bridgeport                    35th & Wallace
# 07/25/2012     Seaway Bank Farmer's Market                     645 E 87th St
# 05/13/2012                         Beverly         W 95th St & S Longwood Dr
# 06/16/2012                     Bronzeville         4400 S. Cottage Grove Ave
# 07/11/2012                         Pullman  E 111th Pl & S Cottage Grove Ave
# 06/07/2012                       Hyde Park                  53rd & Lake Park
# 06/09/2012                   Printer's Row         S Dearborn St & W Polk St
# 06/06/2012                     South Shore        E 70th St & S Jeffery Blvd
# 04/18/2012          Wood Street Farm Stand                    5814 S Wood St
# 05/18/2012       Rowan Tree Garden Society                   501 W Englewood
# 05/19/2012                      Eden Place                4417 S Stewart Ave
# ...

# %%
# now i can use data as an index
df
# Out:
#                           LOCATION                      INTERSECTION  \
# 0                       Bridgeport                    35th & Wallace
# 1      Seaway Bank Farmer's Market                     645 E 87th St
# 2                          Beverly         W 95th St & S Longwood Dr
# 3                      Bronzeville         4400 S. Cottage Grove Ave
# 4                          Pullman  E 111th Pl & S Cottage Grove Ave
# 5                        Hyde Park                  53rd & Lake Park
# 6                    Printer's Row         S Dearborn St & W Polk St
# 7                      South Shore        E 70th St & S Jeffery Blvd
# 8           Wood Street Farm Stand                    5814 S Wood St
# 9        Rowan Tree Garden Society                   501 W Englewood
# 10                      Eden Place                4417 S Stewart Ave
# 11                     61st Street             6100 S Blackstone Ave
# 12         Pilsen Community Market                 1800 S Halsted St
# ...

# %%
# to set the 'START DATE' as the accepted index do this
df
# Out:
#                                   LOCATION                      INTERSECTION  \
# START DATE
# 06/16/2012                      Bridgeport                    35th & Wallace
# 07/25/2012     Seaway Bank Farmer's Market                     645 E 87th St
# 05/13/2012                         Beverly         W 95th St & S Longwood Dr
# 06/16/2012                     Bronzeville         4400 S. Cottage Grove Ave
# 07/11/2012                         Pullman  E 111th Pl & S Cottage Grove Ave
# 06/07/2012                       Hyde Park                  53rd & Lake Park
# 06/09/2012                   Printer's Row         S Dearborn St & W Polk St
# 06/06/2012                     South Shore        E 70th St & S Jeffery Blvd
# 04/18/2012          Wood Street Farm Stand                    5814 S Wood St
# 05/18/2012       Rowan Tree Garden Society                   501 W Englewood
# 05/19/2012                      Eden Place                4417 S Stewart Ave
# ...

# %%
df.loc['06/03/2012']   # get more info on the selected index
# Out:
# LOCATION                      Pilsen Community Market
# INTERSECTION                        1800 S Halsted St
# DAY                                            Sunday
# START TIME                                    9:00 AM
# END TIME                                      3:00 PM
# END DATE                                   10/28/2012
# WEBSITE          http://www.pilsencommunitymarket.org
# TYPE                                      Independent
# LINK ACCEPTED                                     YES
# LATITUDE                                      41.8581
# LONGITUDE                                    -87.6468
# Map                       (41.85806266, -87.64679527)
# Name: 06/03/2012, dtype: object

# %%
df.reset_index(inplace=True)   # return dataframe to its original index

# %%
df
# Out:
#     START DATE                        LOCATION  \
# 0   06/16/2012                      Bridgeport
# 1   07/25/2012     Seaway Bank Farmer's Market
# 2   05/13/2012                         Beverly
# 3   06/16/2012                     Bronzeville
# 4   07/11/2012                         Pullman
# 5   06/07/2012                       Hyde Park
# 6   06/09/2012                   Printer's Row
# 7   06/06/2012                     South Shore
# 8   04/18/2012          Wood Street Farm Stand
# 9   05/18/2012       Rowan Tree Garden Society
# 10  05/19/2012                      Eden Place
# 11  05/12/2012                     61st Street
# 12  06/03/2012         Pilsen Community Market
# 13  06/26/2012                   Columbus Park
# 14  06/06/2012          Wheeler Mansion Market
# 15  06/10/2012           Homegrown Bronzeville
# 16  06/13/2012  Covenant Bank - North Lawndale
#
#                         INTERSECTION        DAY START TIME  END TIME  \
# ...

# %%
'''
    * you can also set an index on the column which have duplicates 
    * for example the DAY column
    # df.loc['DAY']
    * will bring all the dataset containing all the row ['DAY']
'''
